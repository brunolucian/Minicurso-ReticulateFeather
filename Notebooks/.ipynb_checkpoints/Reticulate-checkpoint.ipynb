# %% [markdown]
# O pacote `reticulate` permite a interoperabilidade entre as linguagens Python e R. Ao usar esse pacote é possível utilizar Python do R, traduzir tipos de objetos entre as linguagens, entre outras coisas. Vamos mostrar 4 possibilidades de uso do pacote:
#
# 1. Python no Rmarkdown;
# 2. Importação de módulos Python;
# 3. Source de scripts Python;
# 4. Uso de Python no console.
#
# Vamos ativar o pacote:

# %%
require(reticulate)

# %% [markdown]
# Por padrão, o reticulate encontra a versão do python que é encontrada com a função `Sys.which("python")`. Porém neste ambiente foi instalado o Anaconda, com vários módulos python instalados. Então vamos apontar pro comando `use_python` o diretório do python dentro do Anaconda.

# %%
use_python("/opt/anaconda3/bin/python3")

# %% [markdown]
# ## Python no Rmarkdown
#
# Rmarkdown é a junção de R com a linguagem de marcação markdown, que possibilita a criação de relatórios dinâmicos para, por exemplo, comunicar os resultados de uma análise. Você pode ler mais sobre [neste repositório](https://github.com/leo-filgueira/rmd_semest). Com o `reticulate` (e, obviamente, o python instalado no computador), podemos, além do R, usar o python nas análises a serem comunicadas com o Rmarkdown. Para este tipo de uso do `reticulate`, além desse pacote é necessário ter o pacote `rmarkdown`. Temos um documento feito em Rmarkdown nesse repositório. Dê uma olhada [nesse exemplo](../Intro_reticulate.html).

# %% [markdown]
# ## Importação de módulos Python
#
# Podemos importar numa sessão de R qualquer módulo de Python e usar suas funções no R. Para isso usamos o operador `$`, como acessamos elementos de uma lista do R. Vamos usar o exemplo do módulo `numpy`, e usar sua função `abs`, que encontra o valor absoluto de um número. Vejamos também o valor de pi que encontra-se neste mesmo módulo.

# %%
np <- import("numpy")

np$abs(-10)
np$pi
# Out:
# [1] 10
# [1] 3.141593

# %% [markdown]
# ## Source de scripts python
#
# É possível dar *source* em um script python com a função `source_python`, e usamos do mesmo jeito que a função `source`, para scripts em R. Criamos um script em python que define uma função que soma dois números. Vamos carregar o script via `source_python()`. Em seguida já podemos usar a função que tem como nome `add`.

# %%
source_python("Code//Add.py")

add(1, 2)
# Out:
# [1] 3

# %% [markdown]
# Vamos fazer um exemplo mais complexo. Temos uma função num script em python que recebe dois vetores e ajusta um modelo de regressão linear simples, retornando o coeficiente angular e o coeficiente linear do modelo. Vamos utilizar a massa e altura dos personagens de Star Wars, cujas informações estão na base `starwars`, do pacote `dplyr`).

# %%
source_python("../Code/linear_reg.py")

require(dplyr)

starwars <- starwars %>%
    filter(!is.na(height), !is.na(mass))

linear_reg(starwars$height, starwars$mass)
# Out:
# Loading required package: dplyr
#
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [[1]]
# [1] -13.81031
#
# [[2]]
# [1] 0.638571

# %% [markdown]
# Podemos então plotar as variáveis e a reta ajustada pelo modelo:

# %%
plot(starwars$height, starwars$mass, pch = 20)

abline(unlist(linear_reg(starwars$height, starwars$mass)), col = "blue")
# Out:
# plot without title

# %% [markdown]
# Dessa forma podemos então criar funções em python que façam modelos estatísticos ou de machine learning e visualizar os resultados no R. Devemos ficar atentos nas classes de objetos, e nas conversões feitas. Essa tabela pode ajudar:
#
# | R  | Python | Examples |
# |---|---|---|
# | Single-element vector   | Scalar |  `1`, `1L`, `TRUE`, `"foo"` |
# | Multi-element vector | List  |  `c(1.0, 2.0, 3.0)`, `c(1L, 2L, 3L)` |
# | List of multiple types  | Tuple  |  `list(1L, TRUE, "foo")`
# | Named list | Dict  |  `list(a = 1L, b = 2.0)`, `dict(x = x_data)`
# | Matrix/Array | NumPy ndarray  | `matrix(c(1,2,3,4), nrow = 2, ncol = 2)`
# | Data Frame | Pandas DataFrame | ` data.frame(x = c(1,2,3), y = c("a", "b", "c"))`  |
# | Function | Python function | `function(x) x + 1`
# | Raw  | Python bytearray | `as.raw(c(1:10))` |
# | NULL, TRUE, FALSE  | None, True, False  |  `NULL`, `TRUE`, `FALSE`

# %% [markdown]
# ### Obtendo ajuda
#
# Utilizando a função `py_help` podemos ver a ajuda de uma função. Por exemplo, vamos ver o help da função `abs`, do pacote `numpy`:

# %%
np <- import("numpy")

py_help(np$abs)
# Out:
# Python Help: absolute
#
# Help on ufunc object:
#
# absolute = class ufunc(builtins.object)
#  |  Functions that operate element by element on whole arrays.
#  |
#  |  To see the documentation for a specific ufunc, use `info`.  For
#  |  example, ``np.info(np.sin)``.  Because ufuncs are written in C
#  |  (for speed) and linked into Python with NumPy's ufunc facility,
#  |  Python's help() function finds this page whenever help() is called
#  |  on a ufunc.
#  |
#  |  A detailed explanation of ufuncs can be found in the docs for :ref:`ufuncs`.
#  |
#  |  Calling ufuncs:
#  |  ===============
#  |
#  |  op(*x[, out], where=True, **kwargs)
#  |  Apply `op` to the arguments `*x` elementwise, broadcasting the arguments.
#  |
#  |  The broadcasting rules are:
#  |
#  |  * Dimensions of length 1 may be prepended to either array.
#  |  * Arrays may be repeated along dimensions of length 1.
#  |
#  |  Parameters
#  |  ----------
#  |  *x : array_like
#  |      Input arrays.
# ...

# %% [markdown]
# ### Instalação de pacotes python
#
# Para instalar um pacote python pelo R, basta usar a função `py_install`, com o nome do pacote entre aspas.

# %% [markdown]
# ## Uso de python no console
#
# Um ponto bastante interessante que o `reticulate` permite que executemos código python diretamente no console R. Ao usarmos a função `repl_python`, tudo o que digitarmos é interpretado como código em python até digitarmos `exit`.
